# %%
import matplotlib.pyplot as plt
# plot the data
x = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000, 3000]
y = [2.50120747947285, 1.43355127862261, 0.864780534805491, 0.672211683447639, 0.603297349129265, 0.481443352933992, 0.40015430859936, 0.354405012936127, 0.302625866906665, 0.272571377924385, 0.136152913383544, 0.0914666147773392]

plt.plot(x, y)
plt.xlabel('Size of the matrices')
plt.ylabel('Ratio of time taken by the first part to the second part')
plt.show()

# %%
results = """N: 100
First part: 0.000348
Second part: 0.000533

real    0m0,003s
user    0m0,003s
sys     0m0,000s
N: 200
First part: 0.001319
Second part: 0.00445

real    0m0,007s
user    0m0,007s
sys     0m0,000s
N: 300
First part: 0.002949
Second part: 0.034161

real    0m0,039s
user    0m0,039s
sys     0m0,000s
N: 400
First part: 0.005811
Second part: 0.053942

real    0m0,062s
user    0m0,057s
sys     0m0,004s
N: 500
First part: 0.008322
Second part: 0.119807

real    0m0,130s
user    0m0,126s
sys     0m0,004s
N: 600
First part: 0.0132
Second part: 0.190845

real    0m0,207s
user    0m0,197s
sys     0m0,008s
N: 700
First part: 0.019459
Second part: 0.306028

real    0m0,328s
user    0m0,319s
sys     0m0,008s
N: 800
First part: 0.025341
Second part: 0.51224

real    0m0,540s
user    0m0,528s
sys     0m0,008s
N: 900
First part: 0.034802
Second part: 0.879309

real    0m0,917s
user    0m0,901s
sys     0m0,008s
N: 1000
First part: 0.039008
Second part: 1.10856

real    0m1,152s
user    0m1,142s
sys     0m0,008s
N: 2000
First part: 0.144718
Second part: 9.84837

real    0m9,999s
user    0m9,961s
sys     0m0,028s
N: 3000
First part: 0.342602
Second part: 37.1968

real    0m37,551s
user    0m37,468s
sys     0m0,068s"""

# get the First part and Second part times
first_part = []
second_part = []
for line in results.split('\n'):
    if line.startswith('First part'):
        first_part.append(float(line.split(' ')[2]))
    elif line.startswith('Second part'):
        second_part.append(float(line.split(' ')[2]))

# ratio the times
ratio = []
for i in range(len(first_part)):
    ratio.append(first_part[i] / second_part[i])

# plot the data
plt.plot(x, ratio)
plt.xlabel('Size of the matrices')
plt.ylabel('Ratio of time taken by the first part to the second part')
plt.show()
